# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Input
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"student-mat.csv", sep =";")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    str
#  1   sex         395 non-null    str
#  2   age         395 non-null    int64
#  3   address     395 non-null    str
#  4   famsize     395 non-null    str
#  5   Pstatus     395 non-null    str
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    str
#  9   Fjob        395 non-null    str
#  10  reason      395 non-null    str
#  11  guardian    395 non-null    str
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    str
#  16  famsup      395 non-null    str
#  17  paid        395 non-null    str
#  18  activities  395 non-null    str
#  19  nursery     395 non-null    str
#  20  higher      395 non-null    str
#  21  internet    395 non-null    str
#  22  romantic    395 non-null    str
#  23  famrel      395 non-null    int64
#  24  freetime    395 non-null    int64
#  25  goout       395 non-null    int64
#  26  Dalc        395 non-null    int64
#  27  Walc        395 non-null    int64
#  28  health      395 non-null    int64
#  29  absences    395 non-null    int64
#  30  G1          395 non-null    int64
#  31  G2          395 non-null    int64
#  32  G3          395 non-null    int64
# dtypes: int64(16), str(17)
# memory usage: 122.6 KB

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# std      0.896659    0.998862    1.113278    0.890741    1.287897    1.390303
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     5.708861   10.908861   10.713924   10.415190
# std      8.003096    3.319195    3.761505    4.581443
# min      0.000000    3.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    8.000000
# 50%      4.000000   11.000000   11.000000   11.000000
# 75%      8.000000   13.000000   13.000000   14.000000
# max     75.000000   19.000000   19.000000   20.000000

# %%
cat_column = df.select_dtypes(include='object').columns
print(cat_column)
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='str')
# C:\Users\admin\AppData\Local\Temp\ipykernel_16248\3954451247.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_column = df.select_dtypes(include='object').columns

# %%
le = LabelEncoder()
for col in cat_column:
    df[col]=le.fit_transform(df[col])
df.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1        0        0     4     4     0     4  ...
# 1       0    0   17        1        0        1     1     1     0     2  ...
# 2       0    0   15        1        1        1     1     1     0     2  ...
# 3       0    0   15        1        0        1     4     2     1     3  ...
# 4       0    0   16        1        0        1     3     3     2     2  ...
#
#    famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0       4         3      4     1     1       3         6   5   6   6
# 1       5         3      3     1     1       3         4   5   5   6
# 2       4         3      2     2     3       3        10   7   8  10
# 3       3         2      2     1     1       5         2  15  14  15
# 4       4         3      2     1     2       5         4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    int64
#  1   sex         395 non-null    int64
#  2   age         395 non-null    int64
#  3   address     395 non-null    int64
#  4   famsize     395 non-null    int64
#  5   Pstatus     395 non-null    int64
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    int64
#  9   Fjob        395 non-null    int64
#  10  reason      395 non-null    int64
#  11  guardian    395 non-null    int64
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    int64
#  16  famsup      395 non-null    int64
#  17  paid        395 non-null    int64
#  18  activities  395 non-null    int64
#  19  nursery     395 non-null    int64
#  20  higher      395 non-null    int64
#  21  internet    395 non-null    int64
#  22  romantic    395 non-null    int64
#  23  famrel      395 non-null    int64
#  24  freetime    395 non-null    int64
#  25  goout       395 non-null    int64
#  26  Dalc        395 non-null    int64
#  27  Walc        395 non-null    int64
#  28  health      395 non-null    int64
#  29  absences    395 non-null    int64
#  30  G1          395 non-null    int64
#  31  G2          395 non-null    int64
#  32  G3          395 non-null    int64
# dtypes: int64(33)
# memory usage: 102.0 KB

# %%
X =df.drop('G3', axis = 1)
y=df['G3']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42, test_size=0.2)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(32,)),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1)
])
model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['r2_score']
)

model.summary()
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,737 (18.50 KB)
#  Trainable params: 4,737 (18.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 126.8031 - r2_score: -4.7623 - val_loss: 116.4793 - val_r2_score: -5.8393
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 111.0153 - r2_score: -4.0448 - val_loss: 101.2899 - val_r2_score: -4.9474
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 93.6663 - r2_score: -3.2565 - val_loss: 78.6576 - val_r2_score: -3.6185
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 66.9016 - r2_score: -2.0402 - val_loss: 45.7869 - val_r2_score: -1.6884
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 34.1459 - r2_score: -0.5517 - val_loss: 17.3756 - val_r2_score: -0.0202
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 15.6232 - r2_score: 0.2900 - val_loss: 10.0363 - val_r2_score: 0.4107
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 11.4734 - r2_score: 0.4786 - val_loss: 8.4375 - val_r2_score: 0.5046
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.7536 - r2_score: 0.6022 - val_loss: 7.7682 - val_r2_score: 0.5439
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.5007 - r2_score: 0.6591 - val_loss: 7.4038 - val_r2_score: 0.5653
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.5988 - r2_score: 0.7001 - val_loss: 7.0792 - val_r2_score: 0.5843
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.9732 - r2_score: 0.7286 - val_loss: 6.7607 - val_r2_score: 0.6030
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.4306 - r2_score: 0.7532 - val_loss: 6.6062 - val_r2_score: 0.6121
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.9554 - r2_score: 0.7748 - val_loss: 6.3255 - val_r2_score: 0.6286
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.5063 - r2_score: 0.7952 - val_loss: 6.1151 - val_r2_score: 0.6409
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.1365 - r2_score: 0.8120 - val_loss: 5.9837 - val_r2_score: 0.6487
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.7240 - r2_score: 0.8308 - val_loss: 5.8368 - val_r2_score: 0.6573
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.3810 - r2_score: 0.8464 - val_loss: 5.6985 - val_r2_score: 0.6654
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.0720 - r2_score: 0.8604 - val_loss: 5.5364 - val_r2_score: 0.6749
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.7789 - r2_score: 0.8737 - val_loss: 5.4436 - val_r2_score: 0.6804
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5460 - r2_score: 0.8843 - val_loss: 5.2818 - val_r2_score: 0.6899
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 2.3233 - r2_score: 0.8944 - val_loss: 5.3578 - val_r2_score: 0.6854
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.1192 - r2_score: 0.9037 - val_loss: 5.1686 - val_r2_score: 0.6965
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9283 - r2_score: 0.9124 - val_loss: 5.0800 - val_r2_score: 0.7017
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7714 - r2_score: 0.9195 - val_loss: 5.0633 - val_r2_score: 0.7027
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.6292 - r2_score: 0.9260 - val_loss: 5.0262 - val_r2_score: 0.7049
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5217 - r2_score: 0.9309 - val_loss: 4.9250 - val_r2_score: 0.7108
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.3759 - r2_score: 0.9375 - val_loss: 4.8838 - val_r2_score: 0.7132
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.2788 - r2_score: 0.9419 - val_loss: 4.8526 - val_r2_score: 0.7151
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1945 - r2_score: 0.9457 - val_loss: 4.8135 - val_r2_score: 0.7174
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.1100 - r2_score: 0.9496 - val_loss: 4.8113 - val_r2_score: 0.7175
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.0106 - r2_score: 0.9541 - val_loss: 4.7985 - val_r2_score: 0.7183
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9218 - r2_score: 0.9581 - val_loss: 4.7721 - val_r2_score: 0.7198
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8373 - r2_score: 0.9620 - val_loss: 4.7664 - val_r2_score: 0.7201
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.7760 - r2_score: 0.9647 - val_loss: 4.7580 - val_r2_score: 0.7206
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7171 - r2_score: 0.9674 - val_loss: 4.7346 - val_r2_score: 0.7220
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6624 - r2_score: 0.9699 - val_loss: 4.7876 - val_r2_score: 0.7189
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.6119 - r2_score: 0.9722 - val_loss: 4.8011 - val_r2_score: 0.7181
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5699 - r2_score: 0.9741 - val_loss: 4.7824 - val_r2_score: 0.7192
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5231 - r2_score: 0.9762 - val_loss: 4.8172 - val_r2_score: 0.7171
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4959 - r2_score: 0.9775 - val_loss: 4.7268 - val_r2_score: 0.7225
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4555 - r2_score: 0.9793 - val_loss: 4.8276 - val_r2_score: 0.7165
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4125 - r2_score: 0.9813 - val_loss: 4.8557 - val_r2_score: 0.7149
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3845 - r2_score: 0.9825 - val_loss: 4.8157 - val_r2_score: 0.7172
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3439 - r2_score: 0.9844 - val_loss: 4.7953 - val_r2_score: 0.7184
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3216 - r2_score: 0.9854 - val_loss: 4.7966 - val_r2_score: 0.7184
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2930 - r2_score: 0.9867 - val_loss: 4.8293 - val_r2_score: 0.7164
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2697 - r2_score: 0.9877 - val_loss: 4.8428 - val_r2_score: 0.7156
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2492 - r2_score: 0.9887 - val_loss: 4.8805 - val_r2_score: 0.7134
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2288 - r2_score: 0.9896 - val_loss: 4.8939 - val_r2_score: 0.7126
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2115 - r2_score: 0.9904 - val_loss: 4.8521 - val_r2_score: 0.7151

# %%
loss, mae = model.evaluate(X_test, y_test, verbose=0)

print("Test Loss:", loss)
print("Test MAE:", mae)
# Out:
# Test Loss: 8.395692825317383
# Test MAE: 0.5905547142028809

# %%
predictions = model.predict(X_test)

print("First Prediction:", predictions[0][0])
print("Actual Value:", y_test.iloc[0])
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# First Prediction: 10.334339
# Actual Value: 10

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'r2_score', 'val_loss', 'val_r2_score'])

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['r2_score'], label='Train R²')
plt.plot(history.history['val_r2_score'], label='Validation R²')
plt.title('Training vs Validation R² Score')
plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()
